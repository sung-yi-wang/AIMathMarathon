# %% [markdown]
# 1. 已知直線3x+4y-3=0与直線6x+my+14=0平行，则m的值
# A.6
# B.7
# C.8
# D.-8
#
#
# 2. 两圆x^2+y^2-6x=0和x^2+y^2+8y+12=0的位置關係是
# A.相離
# B.外切
# C.相交
# D.内切
#
#
# 3. 已知两点O(0,0) , A(4,－1)到直線mx+m2y+6=0的距離相等, 则實數m可取的不同值共有
# A.1個
# B.2個
# C.3個
# D.4個
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)
#
# 4. 直線l的方程y=kx+b的圖象如圖所示,则k、b满足
# A.k＞0, b＞0
# B.k＜0, b＜0
# C.k＜0, b＞0
# D.k＞0, b＜0
#
#
#
#
# 5. 下列命题中正确的是
#
# A.过平面ABCD外一点C1作这个平面的垂面有且只有一个
#
# B.过直线AB外一点C1作这条直线的平行平面有且只有一个
#
# C.过直线AB外一点C1作这条直线的垂线有且只有一条
#
# D.过平面ABCD外的一条斜线BC1作这个平面的垂面有且只有一个
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 解答
# 1. C
# 2. B
# 3. C
# 4. B
# 5. C
